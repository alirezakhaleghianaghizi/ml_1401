# %% [markdown]
# <a href="https://colab.research.google.com/github/alirezakhaleghianaghizi/ml_1401/blob/main/q2ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# علیرضا خالقی آناقیزی
# 99101462
#
# سوال 2
#
# در قسمت زیر فایل های مورد نظر را در گوگل درایو ذخیره کردیم و سپسفایل های مورد نظر را لود کرده و دیتا های
# موجود را به ترتیب در ماتریس های
#
# SVT
#
# ذخیره کردیم.

# %%
import csv 
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
filename1='/content/drive/MyDrive/ml/test_data.npy' 
filename2='/content/drive/MyDrive/ml/train_data.npy' 
filename3='/content/drive/MyDrive/ml/validation_data.npy'
# Out:
# Mounted at /content/drive

# %%
T = np.load(filename1, mmap_mode='r')
S = np.load(filename2, mmap_mode='r')
V = np.load(filename3, mmap_mode='r')
print(T)
print(str(len(T))+'\n')
print(S)
print(str(len(S))+'\n')
print(V)
print(str(len(V))+'\n')
# Out:
# [[-0.84428443  0.43219567]
#  [ 0.11741174  0.03325962]
#  [ 1.45874587  0.28870815]
#  [ 0.99669967 -0.50234147]
#  [ 0.78507851  0.15991949]
#  [ 1.72437244  2.20617148]
#  [ 0.25662566  0.22781921]
#  [ 1.89558956  3.27961026]
#  [ 0.71027103  0.77666871]
#  [-0.74307431  0.83886857]
#  [-1.34553455  0.07532852]
#  [-1.6139614   0.33047547]
#  [ 0.88588859  0.01450011]
#  [-0.97789779  0.9327507 ]
#  [-1.07070707  0.75238836]
#  [ 0.35743574  0.32290095]
#  [-1.13951395  0.21803653]
#  [ 1.65676568  1.85211383]
#  [-1.09430943  0.20242484]
#  [ 0.50625063  0.22305293]
#  [-0.46624662  0.16375975]
#  [-0.73427343  0.14116947]
#  [ 0.59305931  0.65651864]
#  [-1.26432643  0.57771818]
#  [ 0.46064606  0.2120837 ]
#  [ 1.30353035 -1.14246949]
#  [ 0.43264326 -0.11212705]
#  [-0.74387439  0.86822753]
#  [-1.89558956  1.29452749]
#  [-0.3210321  -0.35298957]
#  [-0.00620062 -0.69758844]
#  [-1.62236224  0.88307099]
#  [-1.42514251  0.22944119]
#  [-1.6719672   0.38549824]
#  [ 1.28992899 -0.42373186]
#  [ 1.09950995 -0.72362674]
#  [ 0.45064506 -0.45146655]
#  [ 1.5559556   0.67232715]
#  [-1.09230923  0.67936865]
#  [-1.91439144  1.2309955 ]]
# 40
#
# [[-1.93239324  1.59853158]
#  [ 1.19351935 -0.51962868]
#  [-1.8219822   1.65222785]
#  [ 0.62986299  0.17723153]
#  [-0.49384938 -0.15752471]
#  [ 0.10461046 -0.52047304]
#  [-1.65036504  0.91650326]
#  [ 0.51665167 -0.23727129]
#  [ 1.49994999  0.54705307]
#  [ 0.97709771 -0.25195256]
#  [ 0.94629463 -0.51042516]
#  [ 0.89428943 -0.21712669]
#  [ 1.00950095 -0.51150218]
#  [-0.28942894 -0.36000671]
#  [ 0.0650065  -0.31244496]
#  [-1.18551855  0.03380313]
#  [ 0.58865887  0.23481215]
#  [ 0.78827883  0.28558209]
#  [ 0.12541254 -0.79028615]
#  [ 1.58555856  0.69831377]
#  [-0.30583058 -0.3693903 ]
#  [ 0.22382238 -0.37783827]
#  [-0.64546455  0.55225076]
#  [ 0.11541154 -0.50283309]
#  [-1.48954895  0.32233633]
#  [ 1.79077908  3.07231005]
#  [-1.919992    2.30373497]
#  [ 0.44424442  0.51480758]
#  [-1.32873287  0.37184479]
#  [ 1.57115712  1.0986594 ]]
# 30
#
# [[ 1.7559756   3.09995946]
#  [ 0.80588059  0.36850128]
#  [ 1.85358536  3.3802941 ]
#  [ 0.28542854 -0.36009332]
#  [ 1.43394339 -0.37996196]
#  [ 1.94719472  2.15114739]
#  [-1.45714571  0.30467442]
#  [-1.68836884  0.61130086]
#  [ 0.80348035  0.26092148]
#  [-0.81428143  0.35811237]
#  [ 1.33513351  0.04765766]
#  [ 0.02060206 -0.71507412]
#  [ 1.00870087 -0.38971649]
#  [ 1.43994399 -0.34421568]
#  [-0.37183718 -0.23257335]
#  [-0.35943594 -1.18791189]
#  [-1.629963    0.59425016]
#  [-0.27422742 -0.16126773]
#  [-1.62876288  0.60820525]
#  [-1.68036804  1.09216362]
#  [-0.87868787  0.56933873]
#  [-1.17591759  0.68479221]
#  [ 0.46544654  0.10559379]
#  [-0.74427443  0.25872046]
#  [-1.14271427  0.6744882 ]
#  [-0.64906491  1.19165229]
#  [-0.00380038 -0.47102116]
#  [-1.12471247  0.89696252]
#  [ 1.23592359 -1.04590906]
#  [-1.10191019  0.63978021]
#  [-0.52545255  0.35529544]
#  [ 0.05860586 -0.51446225]
#  [ 0.82188219  0.09911931]
#  [-1.6339634   0.55953242]
#  [-1.58515852  0.8012603 ]
#  [-1.31193119  0.42683497]
#  [ 0.94269427 -0.34659633]
#  [-0.51585159  0.09484508]
#  [ 1.81438144  2.93984852]
#  [ 0.94949495 -0.308231  ]]
# 40
